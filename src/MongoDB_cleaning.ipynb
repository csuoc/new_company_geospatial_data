# %% [markdown]
# # MONGO DB ANALYSIS

# %% [markdown]
# ## Import box

# %%
from pymongo import MongoClient
import pandas as pd
import time

# %% [markdown]
# ## Connection with MongoDB

# %%
client = MongoClient("localhost:27017")
db = client["Ironhack"]
coll = db.get_collection("companies")

# %% [markdown]
# ## Find unique values of type category

# %%
unique_cat = pd.DataFrame(coll.find({}, {"category_code":1, "name":1, "_id":0}))

# %%
unique_cat["category_code"].unique()
# Out:
# array(['web', 'enterprise', 'software', 'news', 'social',
#        'network_hosting', 'games_video', 'music', 'mobile', 'search',
#        'advertising', 'messaging', 'security', 'photo_video', 'finance',
#        'hardware', 'ecommerce', 'travel', 'public_relations', 'other',
#        'real_estate', 'semiconductor', 'analytics', 'health', 'legal',
#        'sports', 'biotech', 'cleantech', 'education', 'consulting',
#        'transportation', None, 'hospitality', 'fashion', 'nonprofit',
#        'nanotech', 'automotive', 'design', 'manufacturing', 'government',
#        'local', 'medical'], dtype=object)

# %% [markdown]
# Important categories: games_video, design, mobile. Gamedev could be categorized as design, too. What if the designers of this database mistyped the cateogory? We could have gamedev industries in both.

# %%
filt = {"category_code":"design"}
proj = {"category_code":1, "name":1, "_id":0}

categ = pd.DataFrame(coll.find(filt,proj))
categ.shape
# Out:
# (4, 2)

# %% [markdown]
# Only 4 companies, not good. This is not the best way to target gamedev companies. Let's use the "description" and "overview" tags

# %% [markdown]
# ## Find gaming companies by description, overview, total money raised, country

# %%
df = pd.DataFrame(coll.find({}, {"description":1, "name":1, "_id":0}))

# %%
df.head()
# Out:
#         name                         description
# 0   Wetpaint         Technology Platform Company
# 1  AdventNet          Server Management Software
# 2       Zoho          Online Business Apps Suite
# 3       Digg  user driven social content website
# 4   Facebook                      Social network

# %% [markdown]
# Let's find the ones related with the gaming industry with RegEx. Attributes: description, overview, total money raised, country

# %%
filt = {"$and": [{"description":{"$regex": ".*gam.*|.*Gam.*"}, "overview":{"$regex": ".*gam.*|.*Gam.*"}, 
                  "total_money_raised":{"$regex": "\$.*B|\$.*M"}, "tag_list":{"$regex": ".*gam.*|.*Gam.*"}}]}

proj = {"description":1, "name":1, "_id":0, "description":1, "overview":1, "tag_list":1, "total_money_raised":1, "offices.country_code":1, "number_of_employees":1}

df_regex = pd.DataFrame(coll.find(filt,proj))
df_regex
# Out:
#                              name  number_of_employees  \
# 0                       Thumbplay                 70.0
# 1                           Xfire                  NaN
# 2                          OMGPOP                 50.0
# 3                        FlowPlay                 30.0
# 4                        PlaySpan                  NaN
# 5                      GameLayers                  5.0
# 6                     WildTangent                  NaN
# 7                       PlayFirst                  NaN
# 8                 Challenge Games                  NaN
# 9                       Bunchball                 60.0
# 10                          Zynga                115.0
# 11                      GameDuell                200.0
# 12          Social Gaming Network                100.0
# 13                       Playfish                  NaN
# 14                          Pikum                 15.0
# 15                Realtime Worlds                225.0
# 16                       WeeWorld                  NaN
# 17               Serious Business                 22.0
# 18                          Kabam                650.0
# 19                        Turbine                200.0
# 20                     EnterMedia                  0.0
# 21                       PurePlay                  NaN
# 22                         Gamook                  NaN
# 23                         Garena                 10.0
# 24                         ngmoco                150.0
# 25                        UltiZen                  NaN
# 26  Shattered Reality Interactive                 10.0
# 27                        UltiZen                  NaN
# 28  Shattered Reality Interactive                 10.0
# 29                         Booyah                  NaN
# 30                        GotGame                 15.0
# 31                      CyberArts                 55.0
# 32                        Frenzoo                  7.0
# 33                   Crispy Gamer                  NaN
# 34          Avocado Entertainment                 50.0
# 35                         SCVNGR                 60.0
# 36               Bigfoot Networks                 50.0
# 37                          Exent                100.0
#
#                                              tag_list  \
# 0   mobile, music, video, sharing, gaming, cloud, ...
# 1   games, pc, entertainment, onlinegaming, skillg...
# 2                             dating, gaming, auction
# 3   flowplay, casual-games, virtual-world, avatars...
# 4                        mmog, commerce, gamecommerce
# 5      extension, firefox, game, passive, multiplayer
# 6   games, online-games, video-games, online-adver...
# 7   mobile-games, iphone-games, ipad-games, casual...
# 8   social-games, facebook-games, role-playing-gam...
# 9               games, socialgaming, socialengagement
# 10  facebookapplications, games, socialnetworking,...
# 11  games, social, cross-platform, berlin, fun, go...
# 12                                social, gaming, sgn
# 13  social-gaming, social-games, social-networks, ...
# 14  gaming, social-networks, first-round-capital, ...
# 15                                              games
# 16          social-game, virtual-world, games, avatar
# 17                             facebook, social-games
# 18  social-media, web2-0, social-networking, socia...
# 19  game, online-games, social-gaming, role-playin...
# 20  in-game-advertising, games, online-games, adve...
# 21                         games, poker, online-poker
# 22                                       casual-games
# 23  global-gaming-community-multiplayer-sports-hub...
# 24  gaming, iphone-games, mobile-games, mobile, ip...
# 25                              gaming, on-line-games
# 26  techcrunch50, tc50, games, mmo, social, online...
# 27                              gaming, on-line-games
# 28  techcrunch50, tc50, games, mmo, social, online...
# 29  iphone, real-world-gaming, location-based-gami...
# 30  games, video-games, videos, gaming-videos, new...
# 31   poker-gaming-platform-backgammon-bingo-blackjack
# 32  frenzoo, 3d-avatar, dress-up, fashion-games, 3...
# 33  videogaming, community, editorial, the-game-tr...
# 34  social-game, mobile-game, social-and-mobile-ga...
# 35  mobile, game, princeton, dreamit, google-ventu...
# 36  latency, gaming-network-card, killer-nic, lag,...
# 37    games, videogames, games-on-demand, video-games
#
#                                 description  \
# 0   Music, Videos, Games for Mobile Devices
# 1          Social Gaming Portal & Platform
# 2             Free online multiplayer game
# 3        Virtual world technology and games
# 4                      P2P in-game commerce
# 5               Multiplayer Networked Games
# 6                cross-device games company
# 7                              Mobile games
# 8                       Online social games
# 9                              Gamification
# 10           Network of gaming applications
# 11                      Casual Online Games
# 12                   social gaming platform
# 13                     Social games company
# 14                      Online betting game
# 15       Entertainment software, Videogames
# 16     Social game/virtual world for teens
# 17           Social Game Development Studio
# 18                         Leader in Gaming
# 19        creates and operates online games
# 20              In game advertising company
# 21          play-for-cash online poker game
# 22                      Online Game Sharing
# 23           Global online gaming community
# 24                     Games for the iPhone
# 25                 Art and Game Development
# 26                Online Social Gaming, MMO
# 27                 Art and Game Development
# 28                Online Social Gaming, MMO
# 29     Real-World Social Gaming, iPhone App
# 30    Applications for in-game social media
# 31                Gaming software developer
# 32                    Fashion meets Gaming.
# 33               videogame review community
# 34           Social & Mobile game publisher
# 35            part game, part game platform
# 36                  Premium Gaming Hardware
# 37                   Games on Demand Leader
#
#                                              overview total_money_raised  \
# 0   <p>Thumbplay is a provider of mobile entertain...             $41.5M
# 1   <p>Xfire is the leader in social gaming servic...                $7M
# 2   <p>OMGPOP (formerly known as iminlikewithyou) ...             $16.6M
# 3   <p>FlowPlay, a developer of browser-based virt...             $3.97M
# 4   <p>PlaySpanâ„¢ is the global leader in monetiz...             $46.3M
# 5   <p>GameLayers Inc was a small game design comp...                $2M
# 6   <p>WildTangent is a worldwide cross-device gam...               $84M
# 7   <p>PlayFirst is the global leader in mobile ga...             $37.7M
# 8   <p><a href="http://www.challengegames.com" tit...             $14.5M
# 9   <p>Bunchball is the market leader and visionar...             $12.5M
# 10  <p>Zynga was founded in July 2007 by Mark Pinc...              $860M
# 11  <p>GameDuell – Bringing people together to hav...             $17.5M
# 12  <p>SGN (formerly MindJolt) connects people aro...             $17.1M
# 13  <p>Playfish is a creator of social games for f...               $21M
# 14  <p>Backed by First Round Capital and Virgin, P...             $5.92M
# 15  <p>Realtime Worlds is an entertainment softwar...             $82.8M
# 16  <p>WeeWorld is a social game and virtual world...             $15.5M
# 17  <p>Serious Business is a developer and produce...                $4M
# 18  <p>Kabam is the leader in the western world fo...              $125M
# 19  <p><a href="http://www.turbine.com/" title="Tu...             $76.6M
# 20  <p>Founded in 2005, <a href="http://entermedia...                $1M
# 21  <p><a href="http://player.pureplay.com/" title...               $15M
# 22  <p>Gamook is a platform for people to play &am...              $1.5M
# 23  <p>Garena provides an arena for gamers to chat...                $2M
# 24  <p>ngmoco (&#8220;Next Generation MObile COmpa...             $44.8M
# 25  <p>Ultizen Games Ltd. operates as a game devel...             $15.5M
# 26  <p>Shattered Reality was founded in 2006 with ...              $1.1M
# 27  <p>Ultizen Games Ltd. operates as a game devel...             $15.5M
# 28  <p>Shattered Reality was founded in 2006 with ...              $1.1M
# 29  <p>Booyah, headquartered in San Francisco, is ...             $59.5M
# 30  <p>GotGame creates applications that enable ga...                $1M
# 31  <p>CyberArts offers the Foundation suite of ga...             $16.3M
# 32  <p>Frenzoo is a start up company from Hong Kon...                $1M
# 33  <p>Crispy Gamer (CrispyGamer.com) is a site th...             $8.25M
# 34  <p>Avocado Entertainment is a top-ranked socia...              $1.5M
# 35  <p>SCVNGR is part game, part game platform. Pl...             $40.8M
# 36  <p>Bigfoot Networks is a leading networking te...             $20.8M
# 37  <p>Exent markets and develops software product...                $3M
#
#                                               offices
# 0                           [{'country_code': 'USA'}]
# 1                           [{'country_code': 'USA'}]
# 2   [{'country_code': 'USA'}, {'country_code': 'US...
# 3                           [{'country_code': 'USA'}]
# 4   [{'country_code': 'USA'}, {'country_code': 'US...
# 5                           [{'country_code': 'USA'}]
# 6                           [{'country_code': 'USA'}]
# 7   [{'country_code': 'USA'}, {'country_code': 'IR...
# 8                           [{'country_code': 'USA'}]
# 9                           [{'country_code': 'USA'}]
# 10  [{'country_code': 'USA'}, {'country_code': 'IN...
# 11  [{'country_code': 'USA'}, {'country_code': 'DE...
# 12  [{'country_code': 'USA'}, {'country_code': 'US...
# 13  [{'country_code': 'GBR'}, {'country_code': 'NO...
# 14                          [{'country_code': 'GBR'}]
# 15  [{'country_code': 'GBR'}, {'country_code': 'US...
# 16  [{'country_code': 'USA'}, {'country_code': 'GB...
# 17                          [{'country_code': 'USA'}]
# 18  [{'country_code': 'USA'}, {'country_code': 'CH...
# 19  [{'country_code': 'USA'}, {'country_code': 'US...
# 20                          [{'country_code': 'RUS'}]
# 21                          [{'country_code': 'USA'}]
# 22                          [{'country_code': 'USA'}]
# 23  [{'country_code': 'SGP'}, {'country_code': 'TW...
# 24                          [{'country_code': 'USA'}]
# 25                          [{'country_code': 'CHN'}]
# 26                          [{'country_code': 'USA'}]
# 27                          [{'country_code': 'CHN'}]
# 28                          [{'country_code': 'USA'}]
# 29                          [{'country_code': 'USA'}]
# 30                          [{'country_code': 'USA'}]
# 31  [{'country_code': 'USA'}, {'country_code': 'US...
# 32                          [{'country_code': 'HKG'}]
# 33                          [{'country_code': 'USA'}]
# 34                          [{'country_code': 'KOR'}]
# 35                          [{'country_code': 'USA'}]
# 36  [{'country_code': 'USA'}, {'country_code': 'US...
# 37  [{'country_code': 'USA'}, {'country_code': 'IS...

# %% [markdown]
# ## Filtering by company value
