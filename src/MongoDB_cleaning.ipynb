# %% [markdown]
# # MONGO DB ANALYSIS

# %%
from Functions import *

# %%
df_full = pd.DataFrame(clean_table())

# %%
df_full.head()
# Out:
#         name  number_of_employees  \
# 0  Thumbplay                 70.0
# 1      Xfire                  NaN
# 2     OMGPOP                 50.0
# 2     OMGPOP                 50.0
# 3   FlowPlay                 30.0
#
#                                             tag_list  \
# 0  mobile, music, video, sharing, gaming, cloud, ...
# 1  games, pc, entertainment, onlinegaming, skillg...
# 2                            dating, gaming, auction
# 2                            dating, gaming, auction
# 3  flowplay, casual-games, virtual-world, avatars...
#
#                                description  \
# 0  Music, Videos, Games for Mobile Devices
# 1         Social Gaming Portal & Platform
# 2            Free online multiplayer game
# 2            Free online multiplayer game
# 3       Virtual world technology and games
#
#                                             overview total_money_raised  \
# 0  <p>Thumbplay is a provider of mobile entertain...             $41.5M
# ...

# %%
df_full = df_full.groupby("country_code")["name"].count()

# %%
df_full
# Out:
# country_code
# BEL     1
# CHN     3
# DEU     1
# GBR     4
# HKG     1
# IND     1
# IRL     1
# ISR     1
# KOR     1
# NOR     1
# RUS     1
# SGP     1
# TWN     1
# USA    39
# VNM     2
# Name: name, dtype: int64

# %%
df_full = df_full.loc[(df_full["country_code"] == "USA")]
df_full.
# Out:
#                 name  number_of_employees  \
# 2             OMGPOP                 50.0
# 29            Booyah                  NaN
# 21          PurePlay                  NaN
# 17  Serious Business                 22.0
# 10             Zynga                115.0
#
#                                              tag_list  \
# 2                             dating, gaming, auction
# 29  iphone, real-world-gaming, location-based-gami...
# 21                         games, poker, online-poker
# 17                             facebook, social-games
# 10  facebookapplications, games, socialnetworking,...
#
#                              description  \
# 2          Free online multiplayer game
# 29  Real-World Social Gaming, iPhone App
# 21       play-for-cash online poker game
# 17        Social Game Development Studio
# 10        Network of gaming applications
#
#                                              overview total_money_raised  \
# ...

# %%
df_full = df_full.loc[(df_full["city"] == ["San Francisco","New York"])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 df_full = df_full.loc[(df_full["city"] == ["San Francisco","New York"])]
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\arraylike.py:42, in OpsMixin.__eq__(self, other)
#      40 @unpack_zerodim_and_defer("__eq__")
#      41 def __eq__(self, other):
# ---> 42     return self._cmp_method(other, operator.eq)
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
# ...
